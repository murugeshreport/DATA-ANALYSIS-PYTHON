# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\hp\Downloads\archive\CollegeBasketballPlayers2009-2021.csv')

# %%
data
# Out:
#               player_name              team  conf  GP  Min_per   Ortg   usg  \
# 0           DeAndrae Ross     South Alabama    SB  26     29.5   97.3  16.6
# 1           Pooh Williams          Utah St.   WAC  34     60.9  108.3  14.9
# 2           Jesus Verdejo     South Florida    BE  27     72.0   96.2  21.8
# 3         Mike Hornbuckle        Pepperdine   WCC  30     44.5   97.7  16.0
# 4           Anthony Brown           Pacific    BW  33     56.2   96.5  22.0
# ...                   ...               ...   ...  ..      ...    ...   ...
# 61056      Trey Patterson         Villanova    BE   2      0.3   60.5  19.3
# 61057  Stavros Polatoglou  Northwestern St.  Slnd   4      1.3   28.3   7.1
# 61058          Sandy Ryan            Tulane  Amer   1      0.1    0.0   0.0
# 61059           Ty Larson        Texas Tech   B12   1      0.1    0.0   0.0
# 61060         Jaden Jones           Rutgers   B10   4      1.0   89.6  28.8
#
# ...

# %%
data.isnull().sum()
# Out:
# player_name       0
# team              0
# conf              0
# GP                0
# Min_per           0
#                ...
# stl              38
# blk              38
# pts              38
# Unnamed: 64    4684
# Unnamed: 65      45
# Length: 66, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61061 entries, 0 to 61060
# Data columns (total 66 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   player_name                      61061 non-null  object
#  1   team                             61061 non-null  object
#  2   conf                             61061 non-null  object
#  3   GP                               61061 non-null  int64
#  4   Min_per                          61061 non-null  float64
#  5   Ortg                             61061 non-null  float64
#  6   usg                              61061 non-null  float64
#  7   eFG                              61061 non-null  float64
#  8   TS_per                           61061 non-null  float64
#  9   ORB_per                          61061 non-null  float64
#  10  DRB_per                          61061 non-null  float64
# ...

# %%
data.columns
# Out:
# Index(['player_name', 'team', 'conf', 'GP', 'Min_per', 'Ortg', 'usg', 'eFG',
#        'TS_per', 'ORB_per', 'DRB_per', 'AST_per', 'TO_per', 'FTM', 'FTA',
#        'FT_per', 'twoPM', 'twoPA', 'twoP_per', 'TPM', 'TPA', 'TP_per',
#        'blk_per', 'stl_per', 'ftr', 'yr', 'ht', 'num', 'porpag', 'adjoe',
#        'pfr', 'year', 'pid', 'type', 'Rec Rank', 'ast/tov', 'rimmade',
#        'rimmade+rimmiss', 'midmade', 'midmade+midmiss',
#        'rimmade/(rimmade+rimmiss)', 'midmade/(midmade+midmiss)', 'dunksmade',
#        'dunksmiss+dunksmade', 'dunksmade/(dunksmade+dunksmiss)', 'pick',
#        'drtg', 'adrtg', 'dporpag', 'stops', 'bpm', 'obpm', 'dbpm', 'gbpm',
#        'mp', 'ogbpm', 'dgbpm', 'oreb', 'dreb', 'treb', 'ast', 'stl', 'blk',
#        'pts', 'Unnamed: 64', 'Unnamed: 65'],
#       dtype='object')

# %%
team = data['team'].value_counts().reset_index()

# %%
team=team.rename(columns={'index':'team_name','team':'counts'})

# %% [markdown]
# # TEAM

# %%
team
# Out:
#                team_name  counts
# 0                   Army     226
# 1              Air Force     218
# 2    Arkansas Pine Bluff     215
# 3                   Navy     213
# 4            Jackson St.     211
# ..                   ...     ...
# 357            Merrimack      24
# 358           Bellarmine      15
# 359            Dixie St.      15
# 360         Tarleton St.      15
# 361         UC San Diego      14
#
# [362 rows x 2 columns]

# %%
team.plot.bar(x='team_name',y='counts',figsize=(20,9))
# Out:
# <AxesSubplot:xlabel='team_name'>

# %% [markdown]
# total team 362,top high team Army team

# %% [markdown]
# # TEAM CONFERENCE

# %%
conference = data['conf'].value_counts().reset_index()

# %%
conference = conference.rename(columns={'index':'conf','conf':'counts'})

# %%
conference
# Out:
#     conf  counts
# 0    ACC    2527
# 1    A10    2468
# 2    SEC    2408
# 3    B10    2333
# 4   CUSA    2304
# 5   Slnd    2197
# 6   MEAC    2160
# 7     BE    2122
# 8    MAC    2082
# 9     SB    2023
# 10   OVC    1942
# 11    SC    1920
# 12  SWAC    1919
# 13  BSth    1881
# 14   B12    1860
# 15   NEC    1826
# 16  BSky    1793
# 17  MAAC    1791
# 18   CAA    1772
# 19   MWC    1746
# 20   Pat    1734
# 21   MVC    1690
# 22  Horz    1689
# 23   P12    1685
# 24   WCC    1636
# 25  ASun    1596
# 26    BW    1585
# 27    AE    1533
# 28   Sum    1501
# 29   WAC    1482
# 30   Ivy    1478
# 31  Amer    1199
# 32   ind     429
# 33   P10     415
# 34   GWC     324
# 35   Ind      11

# %%
conference.plot.bar(x='conf',y='counts',figsize=(14,8))
# Out:
# <AxesSubplot:xlabel='conf'>

# %% [markdown]
# # how mony played in tha team

# %%
Games_played=data.groupby(['team'])['GP'].sum()

# %%
Games_played=Games_played.reset_index()

# %%
Games_played
# Out:
#                   team    GP
# 0    Abilene Christian  2376
# 1            Air Force  4160
# 2                Akron  4286
# 3              Alabama  4251
# 4          Alabama A&M  3784
# ..                 ...   ...
# 357         Wright St.  3995
# 358            Wyoming  3774
# 359             Xavier  4257
# 360               Yale  3737
# 361     Youngstown St.  3852
#
# [362 rows x 2 columns]

# %%
Games_played.plot.bar(x='team',y='GP',figsize=(20,7))
# Out:
# <AxesSubplot:xlabel='team'>

# %% [markdown]
# # top 10 played teams

# %%
topGames_played=Games_played.sort_values('GP',ascending = False).head(5)

# %%
topGames_played.plot.barh(x='team',y='GP',figsize=(10,7))
# Out:
# <AxesSubplot:ylabel='team'>

# %% [markdown]
# # total mits

# %%
total_mits = data['Min_per'].sum()
# Out:
# 2267096.5999999996

# %% [markdown]
# # how mony total mits plyed on each team

# %%
Min_per = data.groupby(['team'])['Min_per'].sum()

# %%
team_Min_per=Min_per.reset_index()

# %%
team_Min_per
# Out:
#                   team  Min_per
# 0    Abilene Christian   3999.9
# 1            Air Force   6495.0
# 2                Akron   6484.5
# 3              Alabama   6497.5
# 4          Alabama A&M   6500.3
# ..                 ...      ...
# 357         Wright St.   6500.0
# 358            Wyoming   6500.3
# 359             Xavier   6473.9
# 360               Yale   5999.8
# 361     Youngstown St.   6500.7
#
# [362 rows x 2 columns]

# %%
team_Min_per.plot.barh(x='team',y='Min_per',figsize=(25,15))
# Out:
# <AxesSubplot:ylabel='team'>

# %% [markdown]
# # Top 5 total mits using each team

# %%
top_5 = team_Min_per.sort_values('Min_per',ascending=False).head(5)

# %%
top_5
# Out:
#                team  Min_per
# 282  St. Francis NY   6509.1
# 114      High Point   6508.9
# 161       Manhattan   6508.1
# 301       Texas St.   6507.7
# 7        Alcorn St.   6504.9

# %%
top_5.plot.bar(x='team',y='Min_per',figsize=(9,6))
# Out:
# <AxesSubplot:xlabel='team'>

# %% [markdown]
# # each team Offenceve ratings

# %%
data['Ortg'].isnull().sum()
# Out:
# 0

# %%
ratings=data.groupby(['team'])['Ortg'].sum()

# %%
ratings=ratings.reset_index()

# %%
TOP10ratings=ratings.sort_values('Ortg',ascending=False).head(10)

# %%
TOP10ratings.plot.bar(x='team',y='Ortg',figsize=(11,7))
# Out:
# <AxesSubplot:xlabel='team'>

# %% [markdown]
# # TOP 5 Effictive field goal each team

# %%
fieldgoal=data.groupby(['team'])['eFG'].sum()

# %%
fieldgoal=fieldgoal.reset_index().sort_values('eFG',ascending=False).head(5)

# %%
fieldgoal
# Out:
#                team     eFG
# 1         Air Force  9539.4
# 64        Creighton  9353.4
# 175    Michigan St.  9266.5
# 204  North Carolina  9245.7
# 192            Navy  9172.8

# %%
fieldgoal.plot.barh(x='team',y='eFG',figsize=(11,8))
# Out:
# <AxesSubplot:ylabel='team'>

# %% [markdown]
# # TOP 10 Ture Shooting % team

# %%
data['TS_per']
# Out:
# 0        44.43
# 1        54.48
# 2        47.98
# 3        53.69
# 4        54.31
#          ...
# 61056     0.00
# 61057     0.00
# 61058     0.00
# 61059     0.00
# 61060    25.00
# Name: TS_per, Length: 61061, dtype: float64

# %%
TopShooting = data.groupby(['team'])['TS_per'].sum()

# %%
TopShooting=TopShooting.reset_index()

# %%
TopShooting=TopShooting.sort_values('TS_per',ascending=False).head(5)

# %%
TopShooting
# Out:
#                team    TS_per
# 1         Air Force  10224.12
# 175    Michigan St.   9865.56
# 64        Creighton   9824.02
# 204  North Carolina   9803.93
# 192            Navy   9745.02

# %%
TopShooting.plot.bar(x='team',y='TS_per',figsize=(14,7))
# Out:
# <AxesSubplot:xlabel='team'>

# %% [markdown]
# # Whitch player high ratings

# %%
plyerrading=data.groupby(['player_name'])['Ortg'].sum()

# %%
topplyerrading = plyerrading.reset_index().sort_values('Ortg',ascending=False).head(5)

# %%
topplyerrading
# Out:
#            player_name    Ortg
# 14039  Justin Robinson  1656.8
# 3565   Cameron Johnson  1489.2
# 1374   Anthony Johnson  1471.0
# 4328     Chris Johnson  1393.6
# 23219    Terrell Brown  1356.4

# %%
topplyerrading.plot.barh(x='player_name',y='Ortg',figsize=(14,7))
# Out:
# <AxesSubplot:ylabel='player_name'>

# %% [markdown]
# # high games player person

# %%
highplayergame = data.groupby(['player_name'])['GP'].sum()

# %%
highplayergame=highplayergame.reset_index()

# %%
highplayergameperson = highplayergame.sort_values('GP',ascending=False).head(5)

# %%
highplayergameperson.plot.barh(x='player_name',y='GP',figsize=(10,7))
# Out:
# <AxesSubplot:ylabel='player_name'>

# %% [markdown]
# # high effictive goal person

# %%
goal=data.groupby(['player_name'])['eFG'].sum()

# %%
goal=goal.reset_index()

# %%
goal = goal.sort_values('eFG',ascending=False).head(5)

# %%
goal
# Out:
#            player_name    eFG
# 14039  Justin Robinson  760.6
# 3565   Cameron Johnson  720.4
# 1374   Anthony Johnson  711.9
# 1884   Austin Williams  702.0
# 13468       Josh Davis  665.9

# %%
goal.plot.bar(x='player_name',y='eFG',figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='player_name'>

# %% [markdown]
# Team conference ACC,
# Team High played North Colifornia
# Team efficince rating Air Force
# Team high goal Air Force
# Team best shooting Air Force

# %% [markdown]
# best goal,ratings person Justin Robinson
