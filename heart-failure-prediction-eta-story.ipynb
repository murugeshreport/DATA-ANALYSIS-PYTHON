# %% [markdown]
# # **HEART FAILURE PREDICATION TELL STORY**

# %% [markdown]
# ![](https://tse3.mm.bing.net/th?id=OIP.vqHHf3p5DhOX9yXI3fu6SwHaGW&pid=Api&P=0&w=207&h=177)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec

# %%
data = pd.read_csv('../input/heart-failure-prediction/heart.csv')

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# # Age of  patient Distripution ?

# %%
data['Age']=data['Age'].astype(int)

# %%
color=['#006400','#FF0000','#800000']
age = data['Age'].value_counts().reset_index()
fig = plt.figure(figsize=(15,6))
sns.barplot(x=age['index'],y=age['Age'],palette=color)
sns.despine()
plt.grid(False)
plt.xlabel('Age',weight='semibold')
plt.ylabel('Counts',weight='semibold')
plt.title('Age of Patient Distripution',weight='bold',fontname='copper Black',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Age of Patient Distripution')

# %% [markdown]
# ****In this case very hight heart failure Age 54.****

# %% [markdown]
# # Which Gender Mostly Heart Failure Patients?

# %%
fig = plt.figure(figsize=(14,7))
plt.pie(data['Sex'].value_counts(),labels=data['Sex'].value_counts().index,colors=color,autopct='%1.1F%%')
plt.title('Gender Heart Failure Distriputoion',weight='bold',fontsize=20,fontname='copper Black')
plt.text(1,1,'MOST OF THE PATIENTS MALE IN HEART FAILURE',weight='semibold')
# Out:
# Text(1, 1, 'MOST OF THE PATIENTS MALE IN HEART FAILURE')

# %% [markdown]
# **Male 79% heart Failure compare with Famale**

# %% [markdown]
# # Whitch type of Chest Pain mostly attack?

# %%
fig = plt.figure(figsize=(15,6))
sns.barplot(x=data['ChestPainType'].value_counts().index,y=data['ChestPainType'].value_counts().values,palette=color)
plt.grid(False)
plt.title('Chest Pain Type Destripution',weight='bold',fontsize=20,fontname='copper Black')
# Out:
# Text(0.5, 1.0, 'Chest Pain Type Destripution')

# %% [markdown]
# ****TA: Typical Angina, ATA: Atypical Angina,NAP: Non-Anginal Pain, ASY: Asymptomatic****

# %% [markdown]
# ****ATA: Atypical Angina****
# Atypical angina is a classification of a form of chest pain called angina. The term “atypical” is used to describe a form of anginal chest pain that does not fit the typical presentation. Chest pain is often characterized as squeezing, pressure, heaviness, or tightness. Typical anginal symptoms occur during times of stress or activity due to decreased blood supply to the heart.

# %% [markdown]
# ****TA: Typical Angina****
# Typical angina (TA) is defined as substernal chest pain precipitated by physical exertion or emotional stress and relieved with rest or nitroglycerin. Women and elderly patients are usually have atypical symptoms both at rest and during stress, often in the setting of nonobstructive coronary artery disease (CAD).

# %% [markdown]
# ****NAP: Non-Anginal Pain****
# The term "atypical chest pain" is a waste-basket term that leads physicians to send any patient with chest pain to coronary angiography. In order to avoid this term, we must learn to distinguish atypical angina from nonanginal chest pain before angiography is considered in order to avoid unnecessary invasive procedures. A chest pain is very likely nonanginal if its duration is over 30 minutes or less than 5 seconds, it increases with inspiration, can be brought on with one movement of the trunk or arm, can be brought on by local fingers pressure, or bending forward, or it can be relieved immediately on lying down. There are also many presumptive signs of nonanginal chest pain such as localization with one finger, radiation to the nuchal area, an inframammary primary site, a pain that reaches maximum at the onset, or relief within a few seconds of swallowing food. Cervical root compression pain and esophageal spasm are the greatest mimics of angina since they can both be relieved by nitroglycerin but they have several features which help to rule out angina.

# %% [markdown]
# **ASY: Asymptomatic**
# Asymptomatic left ventricular systolic dysfunction (ALVSD), classified as stage B heart failure, is defined as depressed left ventricular systolic function in the absence of clinical heart failure. Early initiation of therapies in patients with presumed ALVSD has been shown to lead to better outcomes.

# %% [markdown]
#  ****  ASY: Asymptomatic this type of mostly heart failure patients.****

# %% [markdown]
# # Gender vis chestPainType ?

# %%
genderattack = data.groupby(['Sex','ChestPainType'])['Age'].count().reset_index()
male  = genderattack[(genderattack['Sex']=='M')]
fmale = genderattack[(genderattack['Sex']=='F')]

# %%
fig,ax = plt.subplots(1,2,figsize=(18,4))
sns.barplot(x=male['Age'],y=male['ChestPainType'],ax=ax[0],palette=color)
ax[0].grid(False)
ax[0].set_xlabel('')
ax[0].set_title('Male ChestPainType',weight='semibold',fontsize=10)
sns.barplot(x=fmale['Age'],y=fmale['ChestPainType'],ax=ax[1],palette=color)
ax[1].grid(False)
ax[1].set_xlabel('')
ax[1].set_title('Female ChestPainType',weight='semibold',fontsize=10)
plt.suptitle('Male & Female ChestPainType',weight='bold',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Male & Female ChestPainType')

# %%
fig = plt.figure(figsize=(15,6))
sns.barplot(x=data['RestingBP'].value_counts().index,y=data['RestingBP'].value_counts().values,palette=color)
plt.grid(False)
plt.tick_params(axis='x',labelsize=8,rotation=90)
plt.title('RestingBP Destripution',weight='bold',fontsize=20,fontname='copper Black')
# Out:
# Text(0.5, 1.0, 'RestingBP Destripution')

# %% [markdown]
#  Your blood hits the walls of the arteries with some force, which is called blood pressure. Similarly, the heart pushes the blood out when it squeezes itself, and this creates a pressure against the walls of the blood vessels. Your resting blood pressure is the reading taken when you cease from effort for a time.
# ![](https://www.newhealthadvisor.org/images/1HT03940/HBP.jpg)

# %% [markdown]
# ****RestingBP most of patients 120 ****

# %% [markdown]
# # Which Age of Peple mostly RestingBP?

# %%
data['age_intervel'] = pd.cut(x=data['Age'],bins=[25,35,45,55,75])
fig = plt.figure(figsize=(15,6))
sns.barplot(x=data['age_intervel'],y=data['RestingBP'],palette=color)
plt.grid(False)
plt.tick_params(axis='x',labelsize=15,rotation=70)
plt.title('Age vis RestingBP Destripution',weight='bold',fontsize=20,fontname='copper Black')
# Out:
# Text(0.5, 1.0, 'Age vis RestingBP Destripution')

# %% [markdown]
# ****Age 55 - 75 of peple mostly RestingBP****

# %%
fig = plt.figure(figsize=(15,6))
sns.barplot(x=data['age_intervel'],y=data['RestingBP'],hue=data['Sex'],palette=color)
plt.grid(False)
plt.tick_params(axis='x',labelsize=15,rotation=70)
plt.title('Age vis Gender RestingBP Destripution',weight='bold',fontsize=20,fontname='copper Black')
# Out:
# Text(0.5, 1.0, 'Age vis Gender RestingBP Destripution')

# %% [markdown]
# # which Gender more Cholesterol patients?

# %%
Cholesterol = data.groupby(['Sex'])['Cholesterol'].sum().reset_index()

# %%
fig = plt.figure(figsize=(15,6))
sns.barplot(x=Cholesterol['Sex'],y=Cholesterol['Cholesterol'],palette=color)
plt.grid(False)
plt.tick_params(axis='x',labelsize=15,rotation=90)
plt.title('Cholesterol with Gender Destripution',weight='bold',fontsize=20,fontname='copper Black')
# Out:
# Text(0.5, 1.0, 'Cholesterol with Gender Destripution')

# %% [markdown]
# # comparison of RestingBP & Cholesterol

# %%
x=data['RestingBP'].reset_index()
y=data['Cholesterol'].reset_index()
x1=x['index']
x2=x['RestingBP']
y1=y['index']
y2=y['Cholesterol']

# %%
ax,legend=(['l1','l2'])
fig,ax = plt.subplots(figsize=(15,6))
ax.plot(x1,x2,color='g')
ax.plot(y1,y2,color='r')
ax.legend(['RestingBP','Cholesterol'])
plt.title('RestingBP Cholesterol comparison',weight='bold',fontsize=20)
# Out:
# Text(0.5, 1.0, 'RestingBP Cholesterol comparison')

# %% [markdown]
# # RestingECG

# %%
fig = plt.figure(figsize=(15,6))
sns.barplot(x=data['RestingECG'].value_counts().index,y=data['RestingECG'].value_counts().values,palette=color)
plt.grid(False)
plt.tick_params(axis='x',labelsize=10,rotation=90)
plt.title( 'RestingECG Destripution',weight='bold',fontsize=20,fontname='copper Black')
# Out:
# Text(0.5, 1.0, 'RestingECG Destripution')

# %% [markdown]
# ****The electrocardiogram (ECG or EKG) is a test that measures the heart’s electrical activity, and a resting ECG is administered when the patient is at rest. It involves noninvasive recording with adhesive skin electrodes placed on specially prepared spots on the skin, and it plots out the heart's activity on a graph. It is used to determine the health of the heart and circulatory system and to help diagnose issues with associated body systems.****

# %% [markdown]
# # ECG compare with Resting BP and Cholesterol

# %%
ecg = data.groupby(['RestingECG'])['RestingBP','Cholesterol'].sum().reset_index()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
fig = plt.figure(constrained_layout =True,figsize = (12,8))
grid = gridspec.GridSpec(ncols=3,nrows=3,figure=fig)
ax1 = fig.add_subplot(grid[0,:2])
sns.barplot(x=ecg['RestingECG'],y=ecg['RestingBP'],ax=ax1,palette=color)


ax2 = fig.add_subplot(grid[1,:2])
sns.barplot(x=ecg['RestingECG'],y=ecg['Cholesterol'],ax=ax2,palette=color)

ax3 = fig.add_subplot(grid[:,2])
xx = ecg['RestingECG']
xx1 = ecg['Cholesterol']
yy = ecg['RestingECG']
yy1= ecg['RestingBP']
ax3= sns.lineplot(xx,xx1,palette=color)
ax3 = sns.lineplot(yy,yy1,palette=color)
ax3.legend(['RestingBP','Cholesterol'])
plt.suptitle('RestingBP and Cholesterol compare with RestingECG',weight='bold',fontsize=20)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0.98, 'RestingBP and Cholesterol compare with RestingECG')

# %% [markdown]
# ****ECG Normal Cholestrol and  RestingBP  high.****
# ****ECG LVH Cholestrol low  and  RestingBP  high.****
# ****ECG ST Cholestrol low and  RestingBP  high .****

# %% [markdown]
# # Which Age patients of MaxHR high?

# %%
MaxHR = data.groupby(['age_intervel'])['MaxHR'].sum().reset_index()
fig = plt.figure(figsize=(15,6))
sns.barplot(x=MaxHR['age_intervel'],y=MaxHR['MaxHR'],palette=color)
plt.grid(False)
plt.tick_params(axis='x',labelsize=10,rotation=90)
plt.title( 'Age of Patient MaxHR Destripution',weight='bold',fontsize=20,fontname='copper Black')
# Out:
# Text(0.5, 1.0, 'Age of Patient MaxHR Destripution')

# %% [markdown]
# ****Age 55-75 MaxHR high****.
#
# Athletes who use a heart rate monitor as a training aid need to identify their actual maximum heart rate to determine their appropriate training zones. Maximum heart rate (HRmax) can be determined by undertaking a maximum heart rate stress test which, although relatively short, does require you to push your body and your heart to the very limit. It can also be predicted using a formula, but the variation in actual HRmax of 95% of individuals of a given age will lie within a range of ±20 beats/minute

# %%
heart = data.groupby(['HeartDisease']).sum().reset_index()
heart = heart.drop('Age',axis=1)
heart
# Out:
#    HeartDisease  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak
# 0             0      53374        93120         44  60742    167.3
# 1             1      68166        89378        170  64849    647.3

# %% [markdown]
# ****Heart failure this kind of test values there you have check tha heart  high RestingBP,low Cholesterol and low cholesterol ,high FastingBS,high MaxHR,high Oldpeak****
